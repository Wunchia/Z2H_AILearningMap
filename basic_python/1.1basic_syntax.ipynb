# %%
print("hello world")
# Out:
# hello world

# %%
a=1
print(id(a))
a=2
print(id(a))
# Out:
# 140704367450552
# 140704367450584

# %%
a=123
b=1.2
c="aa"
print(type(a))
print(type(b))
print(type(c))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
def use_hex():
    a=5
    print(bin(a))
    print(oct(a))
    print(hex(a))
    print("--------")
    b=-5
    print(bin(b))
    print("===========")

def use_float():
    f=1.23456789123456789
    print(f)
    print("===========")
    
def use_bool():
    print(True)
    print(False)
    print(True+1)
    print(False+1)
    print("===========")
    
use_hex()
use_float()
use_bool()
# Out:
# 0b101
# 0o5
# 0x5
# --------
# -0b101
# ...
# 1.234567891234568
# ...
# True
# False
# 2
# 1
# ...

# %% [markdown]
# 非数字型:
# 字符串、列表、元组、字典、集合

# %%
str1='a'
str2='abc'
print(type(str1))
print(type(str2))
# Out:
# <class 'str'>
# <class 'str'>

# %%
str3='abc\ndef'
print(str3)
# Out:
# abc
# def

# %%
print('abc\'\"def\\')
# Out:
# abc'"def\

# %%
print(ord('0'))
# Out:
# 48

# %%
print(chr(48))
print(chr(65))
# Out:
# 0
# A

# %%
print('-'*50)
# Out:
# --------------------------------------------------

# %%
a=input()
print(a)
# Out:
# A

# %%
print(chr(ord(a)+32))
# Out:
# a

# %%
print('ab'+'cd')
a=input("请输入字母")
print(float(ord(a))+5)
# Out:
# abcd
# 102.0

# %%
score=98.2
print('成绩是%.2f'%score)
# Out:
# 成绩是98.20
