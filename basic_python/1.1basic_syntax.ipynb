# %%
print("hello world")
# Out:
# hello world

# %%
a=1
print(id(a))
a=2
print(id(a))
# Out:
# 140704367450552
# 140704367450584

# %%
a=123
b=1.2
c="aa"
print(type(a))
print(type(b))
print(type(c))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
